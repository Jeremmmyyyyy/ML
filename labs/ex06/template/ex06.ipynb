# %%
# Useful starting lines
# %matplotlib inline

import random
from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt
from test_utils import test
import time


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Support Vector Machines
# ## Classification Using SVM
# Load dataset. We will use a toy dataset from sklearn.

# %%
from sklearn import datasets

# Load dataset
sklearn_dataset = datasets.load_breast_cancer()
Xx = sklearn_dataset.data
y = sklearn_dataset.target * 2 - 1  # labels must be in {-1, 1} for the hinge loss
X = np.ones((Xx.shape[0], Xx.shape[1] + 1))
X[:, :-1] = Xx
print("(N, D) =", X.shape)
# Out:
# (N, D) = (569, 31)

# %% [markdown]
# ## Prepare cost and prediction functions

# %%
def calculate_primal_objective(y, X, w, lambda_):
    """compute the full cost (the primal objective, equation (1) in the exercise pdf),
        that is loss plus regularizer.

    Args:
        X: the full dataset matrix, shape = (num_examples, num_features)
        y: the corresponding +1 or -1 labels, shape = (num_examples)
        w: shape = (num_features)

    Returns:
        scalar, non-negative

    >>> y_test = np.array([1, -1])
    >>> x_test = np.array([[1, 2, 3], [4, 5, 6]])
    >>> w_test = np.array([0, 1, 5])
    >>> calculate_primal_objective(y_test, x_test, w_test, 1)
    31.0
    """
    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
    z = y * (X @ w).T
    hinge_loss = np.maximum(0, 1 - z)
    reg = lambda_ / 2 * w @ w.T
    return hinge_loss.mean() + reg

# %%
test(calculate_primal_objective)
# Out:
# ✅ Your `calculate_primal_objective` passed 4 tests.

# %%
def calculate_accuracy(y, X, w):
    """compute the accuracy on the given dataset (X, y) using the model w.

    Args:
        X: the full dataset matrix, shape = (num_examples, num_features)
        y: the corresponding +1 or -1 labels, shape = (num_examples)
        w: shape = (num_features)

    Returns:
        scalar, between 0 and 1

    >>> y_test = np.array([1, -1])
    >>> x_test = np.array([[1, 2, 3], [4, 5, 6]])
    >>> w_test = np.array([0, 1, 5])
    >>> calculate_accuracy(y_test, x_test, w_test)
    0.5
    """
    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
    return np.mean(np.sign(X @ w) == y)

# %%
test(calculate_accuracy)
# Out:
# ✅ Your `calculate_accuracy` passed 4 tests.

# %% [markdown]
# ## Stochastic Gradient Descent for SVM

# %% [markdown]
# Compute the (stochastic) subgradient for the n-th summand of the SVM optimization objective

# %%
def calculate_stochastic_gradient(y, X, w, lambda_, n, num_examples):
    """compute the stochastic gradient of loss plus regularizer.

    Args:
        X: the dataset matrix, shape = (num_examples, num_features)
        y: the corresponding +1 or -1 labels, shape = (num_examples)
        w: shape = (num_features)
        lambda_: positive scalar number
        n: the index of the (one) datapoint we have sampled
        num_examples: N

    Returns:
        numpy array, shape = (num_features)

    >>> y_test = np.array([1, -1])
    >>> x_test = np.array([[1, 2, 3], [4, 5, 6]])
    >>> w_test = np.array([0, 1, 5])
    >>> calculate_stochastic_gradient(y_test, x_test, w_test, 1, 1, 2)
    array([ 4,  6, 11])
    """

    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
    y_n = y[n]
    x_n = X[n]
    z = -(y_n * x_n) if y_n * x_n @ w < 1 else 0 #we only want the support vectors to be taken into account (support are the ones that are not on the correct side)
    return z + lambda_ * w

# %%
test(calculate_stochastic_gradient)
# Out:
# ✅ Your `calculate_stochastic_gradient` passed 4 tests.

# %% [markdown]
# Implement stochastic gradient descent: Pick a data point uniformly at random and update w based on the gradient for the n-th summand of the objective

# %%
def sgd_for_svm_demo(y, X):
    xs = np.unique(np.round(np.logspace(0, 5, 201)))[:-1]
    max_iter = int(1e5)
    gamma = 1e-4
    lambda_ = 5e1

    num_examples, num_features = X.shape
    w = np.zeros(num_features)
    costs = []
    start = time.time()

    for it in range(max_iter):
        # n = sample one data point uniformly at random data from x
        n = random.randint(0, num_examples - 1)

        grad = calculate_stochastic_gradient(y, X, w, lambda_, n, num_examples)
        w -= gamma / (it + 1) * grad

        cost = calculate_primal_objective(y, X, w, lambda_)

        if it in xs:
            costs += [cost]

    end = time.time()

    print(
        "Final training accuracy = {l} %".format(
            l=np.round(100 * calculate_accuracy(y, X, w), 2)
        )
    )
    print("Training time: " + str(np.round(end - start, 1)) + " seconds ")

    plt.figure()
    plt.title("SGD on primal objective")
    plt.loglog(xs, costs)
    plt.xlabel("Number of iterations")
    plt.ylabel("Primal objective")
    plt.show()


sgd_for_svm_demo(y, X)
# Out:
# Final training accuracy = 90.16 %
# Training time: 1.6 seconds

# %% [markdown]
# ## Coordinate Descent (Ascent) for SVM

# %% [markdown]
# Compute the closed-form update for the n-th variable alpha, in the dual optimization problem, given alpha and the current corresponding w

# %%
def calculate_coordinate_update(y, X, lambda_, alpha, w, n):
    """compute a coordinate update (closed form) for coordinate n.

    Args:
        y: the corresponding +1 or -1 labels, shape = (num_examples)
        X: the dataset matrix, shape = (num_examples, num_features)
        lambda_: positive scalar number
        alpha: vector of dual coordinates, shape = (num_examples)
        w: vector of primal parameters, shape = (num_features)
        n: the coordinate to be updated

    Returns:
        w: updated vector of primal parameters, shape = (num_features)
        alpha: updated vector of dual parameters, shape = (num_examples)

    >>> y_test = np.array([1, -1])
    >>> x_test = np.array([[1., 2., 3.], [4., 5., 6.]])
    >>> w_test = np.array([-0.3, -0.3, -0.3])
    >>> alpha_test = np.array([0.1, 0.1])
    >>> calculate_coordinate_update(y_test, x_test, 1, alpha_test, w_test, 0)
    (array([-0.1,  0.1,  0.3]), array([0.3, 0.1]))
    """
    # calculate the update of coordinate at index=n.
    N = y.size
    x_n, y_n = X[n], y[n]
    old_alpha_n = np.copy(alpha[n])

    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
    
    # alpha[n] = min(max(old_alpha_n + (lambda_ * N - lambda_ * y_n * x_n @ w) / (x_n @ x_n.T), 0), 1)
    alpha[n] = min(max(old_alpha_n + (lambda_ * 1 - lambda_ * y_n * x_n @ w) / (x_n @ x_n.T), 0), 1)

    # w = w + (alpha[n] - old_alpha_n) * y_n * x_n / (lambda_ * N)
    w = w + (alpha[n] - old_alpha_n) * y_n * x_n / (lambda_ * 1)

    return w, alpha

# %%
test(calculate_coordinate_update)
# Out:
# ✅ Your `calculate_coordinate_update` passed 5 tests.

# %%
def calculate_dual_objective(y, X, w, alpha, lambda_):
    """calculate the objective for the dual problem.

    Args:
        y: the corresponding +1 or -1 labels, shape = (num_examples)
        X: the dataset matrix, shape = (num_examples, num_features)
        w: vector of primal parameters, shape = (num_features)
        alpha: vector of dual coordinates, shape = (num_examples)
        lambda_: non negative scalar number

    Output:
        scalar

    >>> y_test = np.array([1, -1])
    >>> x_test = np.array([[1., 2., 3.], [4., 5., 6.]])
    >>> w_test = np.array([-0.3, -0.3, -0.3])
    >>> alpha_test = np.array([0.1, 0.1])
    >>> calculate_dual_objective(y_test, x_test, w_test, alpha_test, 1)
    -0.035
    """
    N = y.size
    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
    Y = np.diag(y)
    # return (np.ones(alpha.shape) @ alpha.T / N) - 1 / (2 * lambda_ * np.power(N, 2)) * alpha @ (Y @ X @ X.T @ Y) @ alpha
    return (np.ones(alpha.shape) @ alpha.T / N) - 1 / (2 * lambda_ ) * alpha @ (Y @ X @ X.T @ Y) @ alpha

# %%
test(calculate_dual_objective)
# Out:
# ✅ Your `calculate_dual_objective` passed 5 tests.

# %%
# Notice that the gap is going to 0
def coordinate_descent_for_svm_demo(y, X):
    max_iter = int(1e5)
    xs = np.unique(np.round(np.logspace(0, 5, 201)))[:-1]
    lambda_ = 5e1
    p_costs, d_costs = [], []

    num_examples, num_features = X.shape
    w = np.zeros(num_features)
    alpha = np.zeros(num_examples)
    start = time.time()

    for it in range(max_iter):
        # n = sample one data point uniformly at random data from x
        n = random.randint(0, num_examples - 1)

        w, alpha = calculate_coordinate_update(y, X, lambda_, alpha, w, n)

        if it in xs:
            # primal objective
            primal_value = calculate_primal_objective(y, X, w, lambda_)
            # dual objective
            dual_value = calculate_dual_objective(y, X, w, alpha, lambda_)
            # store values
            p_costs += [primal_value]
            d_costs += [dual_value]

    end = time.time()
    plt.figure()
    plt.title("Coordinate ascent on dual objective")
    plt.plot(xs, p_costs, label="Primal cost")
    plt.plot(xs, d_costs, label="Dual cost")
    plt.xlabel("Number of iterations")
    plt.xscale("log")
    
    plt.legend()
    plt.show()

    print(
        "Final training accuracy = {l} %".format(
            l=np.round(100 * calculate_accuracy(y, X, w), 2)
        )
    )
    print("Training time: " + str(np.round(end - start, 1)) + " seconds ")
    
    print(d_costs)


coordinate_descent_for_svm_demo(y, X)
# Out:
# Final training accuracy = 92.44 %
# Training time: 1.5 seconds
# [-7.901601073609767e-05, -2.01048493259208e-05, -6.119650344660824e-05, -7.23362754407239e-06, -2.7550502523053387e-05, -5.997839011294149e-05, -5.997839011294149e-05, -5.997839011294149e-05, -8.043702244263474e-05, -8.043702244263474e-05, -8.043702244263474e-05, -8.043702244263474e-05, -8.043702244263474e-05, -0.00010301868147590715, -1.0345529348388072e-05, -1.2890329806294203e-05, -5.3849921175826e-05, -1.5527804657064167e-05, -3.480095798943129e-05, -3.5440365189896084e-05, -2.1690918249260558e-05, -4.591724917066087e-05, -0.00014428401451430